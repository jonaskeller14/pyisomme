# %%
import pyisomme

# %% [markdown]
# # Valid Code

# %%
code = pyisomme.Code("11HEAD0000H3ACXA")

# %%
info = code.get_info()
info
# Out:
# {'Test Object': 'Vehicle 1',
#  'Position': 'Front left',
#  'Main Location': 'Head',
#  'Fine Location 1': 'Not defined',
#  'Fine Location 2': 'Not defined',
#  'Fine Location 3': 'Hybrid III Mid-Sized Adult Male Dummy',
#  'Physical Dimension': 'Acceleration',
#  'Direction': 'Longitudinal',
#  'Filter Class': 'CFC 1000'}

# %%
code.get_default_unit()
# Out:
# Unit("m / s2")

# %% [markdown]
# # Invalid Code

# %%
pyisomme.Code("11HEAD0000H3ACX")
# Out:
# ---------------------------------------------------------------------------
# InvalidCodeError                          Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pyisomme.Code("11HEAD0000H3ACX")
#
# File D:\20220211_pyisomme\pyisomme\code.py:101, in Code.__new__(cls, code)
#      99 def __new__(cls, code: str) -> Code:
#     100     if not _CODE_REGEX.fullmatch(code):
# --> 101         raise InvalidCodeError(
#     102             f"Invalid code '{code}'. Code must be 16 characters long, containing only "
#     103             "letters, digits and '?' wildcards."
#     104         )
#     105     return super().__new__(cls, code)
#
# InvalidCodeError: Invalid code '11HEAD0000H3ACX'. Code must be 16 characters long, containing only letters, digits and '?' wildcards.

# %%
pyisomme.Code("11HEAD0000XXACXA").get_info()
# Out:
# '11HEAD0000XXACXA' has no definition for Fine Location 3.
# {'Test Object': 'Vehicle 1',
#  'Position': 'Front left',
#  'Main Location': 'Head',
#  'Fine Location 1': 'Not defined',
#  'Fine Location 2': 'Not defined',
#  'Physical Dimension': 'Acceleration',
#  'Direction': 'Longitudinal',
#  'Filter Class': 'CFC 1000'}
