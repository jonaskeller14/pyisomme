# %%
# %%bash
# "/mnt/c/Program Files/Python39/python.exe" -m pyisomme --help
# Out:
# usage: __main__.py [-h] [-v] {list,merge,report,plot} ...
#
# positional arguments:
#   {list,merge,report,plot}
#     merge               Merge ISO-MMEs
#     report              Create a Report
#     plot                Plot Channels
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -v, --verbose         Verbose mode
