# %%
import pyisomme

# %%
v1 = pyisomme.Isomme().read("../data/nhtsa/11391/11391.mme", "11NECKUP????FO??")
v2 = pyisomme.Isomme().read("../data/nhtsa/14084/14084.mme", "11NECKUP????FO??")
v3 = pyisomme.Isomme().read("../data/nhtsa/14065/14065.mme", "11NECKUP????FO??")

v1.print_channel_list()
v2.print_channel_list()
v3.print_channel_list()
# Out:
# 11391 - Channel List:
# 	001	11NECKUP0000FOXP
# 	002	11NECKUP0000FOYP
# 	003	11NECKUP0000FOZP
# 14084 - Channel List:
# 	001	11NECKUP0000FOXP
# 	002	11NECKUP0000FOYP
# 	003	11NECKUP0000FOZP
# 14065 - Channel List:
# 	001	11NECKUP0000FOXP
# 	002	11NECKUP0000FOYP
# 	003	11NECKUP0000FOZP

# %%
pyisomme.plot_1([v1, v2, v3], "11NECKUP0000FOXP")

# %%
pyisomme.plot_4_xyzr([v1, v2, v3], "11NECKUP0000FO?D")  # Plot filtered channels, 2x2-Layout

# %%
pyisomme.plot_4_xyzr([v1, v2, v3], "11NECKUP0000FO?D", 4, 1)  # 4x1-Layout

# %%
pyisomme.plot_1_xyzr([v1], "11NECKUP0000FOXP")
